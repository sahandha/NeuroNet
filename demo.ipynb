# %%
from NeuroNet import *

# %%
b = Brain()
b.Simulate()
# Out:
# Neuron 1
# Voltage: -0.0050687290586962025
# Current: 0.00867496354188368
# ...
# Neuron 1
# Voltage: -0.010274829542246955
# Current: 0.017199710530398454
# ...
# Neuron 1
# Voltage: -0.015618166977344267
# Current: 0.025574027890336082
# ...
# Neuron 1
# Voltage: -0.021098600014239934
# Current: 0.033797706381475764
# ...
# Neuron 1
# Voltage: -0.026715979910141435
# Current: 0.0418705406491354
# ...
# Neuron 1
# Voltage: -0.0324701499782718
# Current: 0.04979232928085821
# ...
# Neuron 1
# Voltage: -0.038360945001753514
# Current: 0.057562874869606005
# ...
# Neuron 1
# Voltage: -0.0443881906114991
# Current: 0.06518198408383706
# ...
# Neuron 1
# Voltage: -0.05055170262731678
# Current: 0.07264946774485254
# ...
# Neuron 1
# Voltage: -0.056851286361468724
# Current: 0.07996514091180171
# ...
# Neuron 1
# Voltage: -0.06328673588395223
# Current: 0.08712882297474106
# ...
# Neuron 1
# Voltage: -0.06985783324881084
# Current: 0.09414033775614786
# ...
# Neuron 1
# Voltage: -0.0765643476808234
# Current: 0.10099951362129263
# ...
# Neuron 1
# ...

# %%
b._Neurons[0]._GM.Flow
# Out:
# <bound method Neuron.Flow_FHN of <NeuroNet.Neuron object at 0x104e57cc0>>

# %%
b._Neurons[0]._GM.Simulate(Flow=b._Neurons[0]._GM.Flow,UpdateMethod="RungeKutta")
plt.rcParams["figure.figsize"] = (13, 4)
b._Neurons[0]._GM.PlotState(states={1:"V",2:"w"})
